# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshopShrivastava/Assignment-2-Set-1-Q1-Basic-Statistics-level_2-/blob/main/Assignment_2_Set_1_Q1_(Basic_Statistics_level_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2
#
# Name of company and their measure -
#
# Allied Signal 24.23%, Bankers Trust 25.53%, General Mills 25.41%, ITT industries 24.14%, J.P.Morgan & Co. 29.62%, Lehman Brothers 28.25%, Marriott 25.81%, MCI 24.39%, Merrill Lynch 40.26%, Microsoft 32.95%, Morgan Stanley 91.36%, Sun Microsystems 25.99%, Travelers 39.42%, US Airways 26.71%, Warner-Lambert 35.00%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = pd.Series ([ 24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])
Column = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems',
'Travelers', 'US Airways', 'Warner-Lambert']
data
# Out:
# 0     24.23
# 1     25.53
# 2     25.41
# 3     24.14
# 4     29.62
# 5     28.25
# 6     25.81
# 7     24.39
# 8     40.26
# 9     32.95
# 10    91.36
# 11    25.99
# 12    39.42
# 13    26.71
# 14    35.00
# dtype: float64

# %%
plt.figure(figsize=(7,7))
plt.pie(data, labels= Column, autopct='%1.2f%%',shadow=True)
plt.show()

# %%
plt.boxplot(data)
plt.show()

# %% [markdown]
# There is one outlier : Morgan Stanley 91.36%

# %%
# Mean
data.mean()
# Out:
# 33.27133333333333

# %%
# Standard Deviation
data.std()
# Out:
# 16.945400921222028

# %%
# Variance
data.var()
# Out:
# 287.1466123809524
