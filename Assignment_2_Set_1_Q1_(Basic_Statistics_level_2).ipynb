# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshopShrivastava/Assignment-2-Set-1-Q1-Basic-Statistics-level_2-/blob/main/Assignment_2_Set_1_Q1_(Basic_Statistics_level_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2
#
# Name of company :-
#
# Allied Signal 24.23%
#
# Bankers Trust 25.53%
#
# General Mills 25.41%
#
# ITT Industries 24.14%
#
# J.P.Morgan & Co. 29.62%
#
# Lehman Brothers 28.25%
#
# Marriott 25.81%
#
# MCI 24.39%
#
# Merrill Lynch 40.26%
#
# Microsoft 32.95%
#
# Morgan Stanley 91.36%
#
# Sun Microsystems 25.99%
#
# Travelers 39.42%
#
# US Airways 26.71%
#
# Warner-Lambert 35.00%

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.Series ([ 24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])
Column = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems',
'Travelers', 'US Airways', 'Warner-Lambert']
data
# Out:
# 0     24.23
# 1     25.53
# 2     25.41
# 3     24.14
# 4     29.62
# 5     28.25
# 6     25.81
# 7     24.39
# 8     40.26
# 9     32.95
# 10    91.36
# 11    25.99
# 12    39.42
# 13    26.71
# 14    35.00
# dtype: float64

# %%
plt.figure(figsize=(7,7))
plt.pie(data, labels= Column, autopct='%1.2f%%',shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7faa8afe4790>,
#   <matplotlib.patches.Wedge at 0x7faa8afe4990>,
#   <matplotlib.patches.Wedge at 0x7faa8b03f050>,
#   <matplotlib.patches.Wedge at 0x7faa8b11bc10>,
#   <matplotlib.patches.Wedge at 0x7faa8b2a2bd0>,
#   <matplotlib.patches.Wedge at 0x7faa8b10ec10>,
#   <matplotlib.patches.Wedge at 0x7faa8b0396d0>,
#   <matplotlib.patches.Wedge at 0x7faa8afd4250>,
#   <matplotlib.patches.Wedge at 0x7faa8b2a28d0>,
#   <matplotlib.patches.Wedge at 0x7faa8b10e650>,
#   <matplotlib.patches.Wedge at 0x7faa8b1877d0>,
#   <matplotlib.patches.Wedge at 0x7faa8b1791d0>,
#   <matplotlib.patches.Wedge at 0x7faa8b1e8050>,
#   <matplotlib.patches.Wedge at 0x7faa8b1e8c90>,
#   <matplotlib.patches.Wedge at 0x7faa8b1ed090>],
#  [Text(1.087229608003385, 0.16712803319852174, 'Allied Signal'),
#   Text(0.9828289461480074, 0.49401139927495336, 'Bankers Trust'),
#   Text(0.7770213716923852, 0.7786127329637529, 'General Mills'),
#   Text(0.500589114389161, 0.9794950426393569, 'ITT Industries'),
#   Text(0.14701343081593748, 1.09013166689154, 'J.P.Morgan & Co.'),
#   Text(-0.25102787165672724, 1.0709738594622624, 'Lehman Brothers'),
#   Text(-0.5940932351165659, 0.9257716932315078, 'Marriott'),
#   Text(-0.852379310544051, 0.6953053364935786, 'MCI'),
#   Text(-1.057980932673138, 0.30112513362400867, 'Merrill Lynch'),
#   Text(-1.0815202792052954, -0.20078318073907453, 'Microsoft'),
#   Text(-0.6253838571430779, -0.9049281911979793, 'Morgan Stanley'),
#   Text(0.14694509767976283, -1.0901408800094992, 'Sun Microsystems'),
#   Text(0.57095205164786, -0.9402200565394782, 'Travelers'),
#   Text(0.902381559110251, -0.6290528767740856, 'US Airways'),
#   Text(1.0734100571373322, -0.24039727377079212, 'Warner-Lambert')],
#  [Text(0.5930343316382098, 0.09116074538101185, '4.86%'),
#   Text(0.5360885160807313, 0.26946076324088364, '5.12%'),
#   Text(0.4238298391049373, 0.42469785434386514, '5.09%'),
#   Text(0.2730486078486332, 0.534270023257831, '4.84%'),
#   Text(0.08018914408142043, 0.5946172728499308, '5.94%'),
#   Text(-0.1369242936309421, 0.5841675597066885, '5.66%'),
#   Text(-0.3240508555181268, 0.5049663781262769, '5.17%'),
#   Text(-0.46493416938766413, 0.37925745626922464, '4.89%'),
#   Text(-0.5770805087308025, 0.1642500728858229, '8.07%'),
#   Text(-0.5899201522937975, -0.10951809858494974, '6.60%'),
#   Text(-0.3411184675325879, -0.4935971951988977, '18.31%'),
#   Text(0.0801518714616888, -0.5946222981869995, '5.21%'),
#   Text(0.31142839180792364, -0.512847303566988, '7.90%'),
#   Text(0.49220812315104595, -0.343119750967683, '5.35%'),
#   Text(0.5854963948021812, -0.13112578569315933, '7.01%')])

# %%
plt.boxplot(data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7faa7bd4ebd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7faa7bd57c10>,
#   <matplotlib.lines.Line2D at 0x7faa7bd5e190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7faa7bd5ec50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7faa7bd5e710>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7faa7bd57190>,
#   <matplotlib.lines.Line2D at 0x7faa7bd576d0>]}

# %% [markdown]
# There is one outlier : Morgan Stanley 91.36%

# %%
# Mean
data.mean()
# Out:
# 33.27133333333333

# %%
# Standard Deviation
data.std()
# Out:
# 16.945400921222028

# %%
# Variance
data.var()
# Out:
# 287.1466123809524
